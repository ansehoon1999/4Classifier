# %% [markdown]
# <a href="https://colab.research.google.com/github/ansehoon1999/4Classifier/blob/main/%EC%84%B8%ED%9B%88%26%EA%B8%B0%EC%98%81_%EB%8D%B0%EC%B2%AD%EC%BA%A0/%EB%B0%B0%EB%8B%AC%EC%9D%B8%EA%B5%AC_%EB%8D%B0%EC%9D%B4%ED%84%B0_%EC%A0%95%EC%A0%9C(%EC%83%81%EB%AA%A9).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
col1 = []
col2 = []
col3 = []
col4 = []


file = "/content/drive/MyDrive/11_2019년_성연령별인구.txt"
f = open(file, 'r')
line = f.readline()

while True:

    line = f.readline()
    if not line: 
      break
    l = line.split('^')

    col1.append(l[0])
    col2.append(l[1])
    col3.append(l[2])
    col4.append(l[3])

f.close()

# %% [markdown]
# 나이 정보
# - 10대: in_age_003, in_age_004
# - 20대: in_age_005, in_age_006
# - 30대: in_age_007, in_age_008
# - 40대: in_age_009, in_age_010
# - 50대: in_age_011, in_age_012
# - 60대: in_age_013, in_age_014
# - 70대: in_age_015, in_age_016

# %%
for i in range(len(col4)) :
  if col4[i] == 'N/A\n' or col4[i] == 'N/A' :
      col4[i] = '2.5'
  
  col4[i] = float(col4[i])

# %%
import pandas as pd

df = pd.DataFrame({
    "집계구코드": col2,
    "나이코드": col3,
    "인원수": col4,
    })

# %%
df.set_index('나이코드', inplace = True)

# %%
df.head()
# Out:
#                     집계구코드  인원수
# 나이코드
# in_age_001  1101053010001  8.0
# in_age_002  1101053010001  2.5
# in_age_003  1101053010001  7.0
# in_age_004  1101053010001  8.0
# in_age_005  1101053010001  9.0

# %%
#10대
df_10 = df.loc[['in_age_003', 'in_age_004']]

#20대
df_20 = df.loc[['in_age_005', 'in_age_006']]
#30대
df_30 = df.loc[['in_age_007', 'in_age_008']]
#40대
df_40 = df.loc[['in_age_009', 'in_age_010']]
#50대
df_50 = df.loc[['in_age_003', 'in_age_012']]
#60대 이상
df_60up = df.loc[['in_age_013', 'in_age_014', 'in_age_015', 'in_age_016']]


for i in range(len(df_10)) :
  df_10.iloc[i,1] =  df_10.iloc[i,1] 


for i in range(len(df_20)) :
  df_20.iloc[i,1] =  df_20.iloc[i,1] 


for i in range(len(df_30)) :
  df_30.iloc[i,1] =  df_30.iloc[i,1] 

for i in range(len(df_40)) :
  df_40.iloc[i,1] =  df_40.iloc[i,1]

for i in range(len(df_50)) :
  df_50.iloc[i,1] =  df_50.iloc[i,1] 

for i in range(len(df_60up)) :
  df_60up.iloc[i,1] =  df_60up.iloc[i,1]

# %%
#10대
df_code = df_10['집계구코드']
df = df_10.groupby(df_10['집계구코드'])
df_final = round(pd.DataFrame(df.sum()))
df_final.rename(columns = {"인원수": "10대인구수"}, inplace = True)
df_final_x10 = df_final

print(df_final_x10)



tmp = []
for i in range(len(df_final)) :
  tmp.append(df_final.iloc[i,0])


a = df_final.index
a_list = []

for i in range(len(a)) :
  a_list.append(a[i])

df_final_10 = pd.DataFrame({"집계구코드":a_list, "인구수":tmp})
print(df_final_10)
tmp_10 = tmp
# Out:
#                10대인구수
# 집계구코드
# 1101053010001    15.0
# 1101053020001    46.0
# 1101053020002    43.0
# 1101053020003    34.0
# 1101053020004    24.0
# ...               ...
# 1125074022801    23.0
# 1125074023001    47.0
# 1125074023002    54.0
# 1125074023003    55.0
# 1125074023004    36.0
#
# [18540 rows x 1 columns]
#                집계구코드   인구수
# 0      1101053010001  15.0
# 1      1101053020001  46.0
# 2      1101053020002  43.0
# 3      1101053020003  34.0
# 4      1101053020004  24.0
# ...              ...   ...
# 18535  1125074022801  23.0
# 18536  1125074023001  47.0
# 18537  1125074023002  54.0
# 18538  1125074023003  55.0
# 18539  1125074023004  36.0
#
# [18540 rows x 2 columns]

# %%
#20대
df_code = df_20['집계구코드']
df = df_20.groupby(df_20['집계구코드'])
df_final = round(pd.DataFrame(df.sum()))
df_final.rename(columns = {"인원수": "20대인구수"}, inplace = True)
df_final_x20 = df_final
print(df_final_x20)


tmp = []
for i in range(len(df_final)) :
  tmp.append(df_final.iloc[i,0])


a = df_final.index
a_list = []

for i in range(len(a)) :
  a_list.append(a[i])

df_final_20 = pd.DataFrame({"집계구코드":a_list, "인구수":tmp})
print(df_final_20)

tmp_20 = tmp
# Out:
#                20대인구수
# 집계구코드
# 1101053010001    59.0
# 1101053020001    56.0
# 1101053020002    58.0
# 1101053020003    49.0
# 1101053020004    59.0
# ...               ...
# 1125074022801    71.0
# 1125074023001    41.0
# 1125074023002    55.0
# 1125074023003    65.0
# 1125074023004    49.0
#
# [18550 rows x 1 columns]
#                집계구코드   인구수
# 0      1101053010001  59.0
# 1      1101053020001  56.0
# 2      1101053020002  58.0
# 3      1101053020003  49.0
# 4      1101053020004  59.0
# ...              ...   ...
# 18545  1125074022801  71.0
# 18546  1125074023001  41.0
# 18547  1125074023002  55.0
# 18548  1125074023003  65.0
# 18549  1125074023004  49.0
#
# [18550 rows x 2 columns]

# %%
#30대
df_code = df_30['집계구코드']
df = df_30.groupby(df_30['집계구코드'])
df_final = round(pd.DataFrame(df.sum()))

df_final.rename(columns = {"인원수": "30대인구수"}, inplace = True)
df_final_x30 = df_final
print(df_final_x30)


tmp = []
for i in range(len(df_final)) :
  tmp.append(df_final.iloc[i,0])


a = df_final.index
a_list = []

for i in range(len(a)) :
  a_list.append(a[i])

df_final_30 = pd.DataFrame({"집계구코드":a_list, "인구수":tmp})
print(df_final_30)

tmp_30 = tmp
# Out:
#                30대인구수
# 집계구코드
# 1101053010001    86.0
# 1101053020001    45.0
# 1101053020002    53.0
# 1101053020003    51.0
# 1101053020004    59.0
# ...               ...
# 1125074022801    78.0
# 1125074023001    57.0
# 1125074023002    61.0
# 1125074023003   100.0
# 1125074023004    81.0
#
# [18547 rows x 1 columns]
#                집계구코드    인구수
# 0      1101053010001   86.0
# 1      1101053020001   45.0
# 2      1101053020002   53.0
# 3      1101053020003   51.0
# 4      1101053020004   59.0
# ...              ...    ...
# 18542  1125074022801   78.0
# 18543  1125074023001   57.0
# 18544  1125074023002   61.0
# 18545  1125074023003  100.0
# 18546  1125074023004   81.0
#
# [18547 rows x 2 columns]

# %%
#40대
df_code = df_40['집계구코드']
df = df_40.groupby(df_40['집계구코드'])
df_final = round(pd.DataFrame(df.sum()))

df_final.rename(columns = {"인원수": "40대인구수"}, inplace = True)
df_final_x40 = df_final
print(df_final_x40)


tmp = []
for i in range(len(df_final)) :
  tmp.append(df_final.iloc[i,0])

a = df_final.index
a_list = []

for i in range(len(a)) :
  a_list.append(a[i])

df_final_40 = pd.DataFrame({"집계구코드":a_list, "인구수":tmp})
print(df_final_40)

tmp_40 = tmp
# Out:
#                40대인구수
# 집계구코드
# 1101053010001    47.0
# 1101053020001    89.0
# 1101053020002    73.0
# 1101053020003    71.0
# 1101053020004    55.0
# ...               ...
# 1125074022801    57.0
# 1125074023001    69.0
# 1125074023002    86.0
# 1125074023003    94.0
# 1125074023004    83.0
#
# [18538 rows x 1 columns]
#                집계구코드   인구수
# 0      1101053010001  47.0
# 1      1101053020001  89.0
# 2      1101053020002  73.0
# 3      1101053020003  71.0
# 4      1101053020004  55.0
# ...              ...   ...
# 18533  1125074022801  57.0
# 18534  1125074023001  69.0
# 18535  1125074023002  86.0
# 18536  1125074023003  94.0
# 18537  1125074023004  83.0
#
# [18538 rows x 2 columns]

# %%
#50대
df_code = df_50['집계구코드']
df = df_50.groupby(df_50['집계구코드'])
df_final = round(pd.DataFrame(df.sum()))
df_final.rename(columns = {"인원수": "50대인구수"}, inplace = True)
df_final_x50 = df_final
print(df_final_x50)
tmp = []
for i in range(len(df_final)) :
  tmp.append(df_final.iloc[i,0])


a = df_final.index
a_list = []

for i in range(len(a)) :
  a_list.append(a[i])

df_final_50 = pd.DataFrame({"집계구코드":a_list, "인구수":tmp})
print(df_final_50)

tmp_50 = tmp
# Out:
#                50대인구수
# 집계구코드
# 1101053010001    37.0
# 1101053020001    42.0
# 1101053020002    46.0
# 1101053020003    35.0
# 1101053020004    60.0
# ...               ...
# 1125074022801    47.0
# 1125074023001    65.0
# 1125074023002    68.0
# 1125074023003    85.0
# 1125074023004    65.0
#
# [18538 rows x 1 columns]
#                집계구코드   인구수
# 0      1101053010001  37.0
# 1      1101053020001  42.0
# 2      1101053020002  46.0
# 3      1101053020003  35.0
# 4      1101053020004  60.0
# ...              ...   ...
# 18533  1125074022801  47.0
# 18534  1125074023001  65.0
# 18535  1125074023002  68.0
# 18536  1125074023003  85.0
# 18537  1125074023004  65.0
#
# [18538 rows x 2 columns]

# %%
#60대 이상
df_code = df_60up['집계구코드']
df = df_60up.groupby(df_60up['집계구코드'])
df_final = round(pd.DataFrame(df.sum()))
df_final.rename(columns = {"인구수": "60대인구수"}, inplace = True)
df_final_x60 = df_final
print(df_final_x60)

tmp = []
for i in range(len(df_final)) :
  tmp.append(df_final.iloc[i,0])


a = df_final.index
a_list = []

for i in range(len(a)) :
  a_list.append(a[i])

df_60up = pd.DataFrame({"집계구코드":a_list, "인구수":tmp})
print(df_60up)

tmp_60 = tmp
# Out:
#                60대인구수
# 집계구코드
# 1101053010001    68.0
# 1101053020001    92.0
# 1101053020002    67.0
# 1101053020003    96.0
# 1101053020004    98.0
# ...               ...
# 1125074022801    87.0
# 1125074023001   138.0
# 1125074023002   112.0
# 1125074023003   154.0
# 1125074023004   131.0
#
# [18538 rows x 1 columns]
#                집계구코드    인구수
# 0      1101053010001   68.0
# 1      1101053020001   92.0
# 2      1101053020002   67.0
# 3      1101053020003   96.0
# 4      1101053020004   98.0
# ...              ...    ...
# 18533  1125074022801   87.0
# 18534  1125074023001  138.0
# 18535  1125074023002  112.0
# 18536  1125074023003  154.0
# 18537  1125074023004  131.0
#
# [18538 rows x 2 columns]

# %%
x = df_final_x10.join(df_final_x20, how='right')
x = x.join(df_final_x30, how='right')
x = x.join(df_final_x40, how='right')
x = x.join(df_final_x50, how='right')
x = x.join(df_final_x60, how='right')

a = x.index
a_list = []

for i in range(len(a)) :
  a_list.append(a[i])



sum_list = []
for i in range(len(df)) :
  sum = x.iloc[i,0] + x.iloc[i,1] + x.iloc[i,2] + x.iloc[i,3] + x.iloc[i,4] + x.iloc[i,5]
  sum_list.append(sum) 


x['집계구코드'] = a_list
x['합계'] = sum_list
x
# Out:
#                10대인구수  20대인구수  30대인구수  ...  60대인구수          집계구코드     합계
# 집계구코드                                  ...
# 1101053010001    15.0    59.0    86.0  ...    68.0  1101053010001  312.0
# 1101053020001    46.0    56.0    45.0  ...    92.0  1101053020001  370.0
# 1101053020002    43.0    58.0    53.0  ...    67.0  1101053020002  340.0
# 1101053020003    34.0    49.0    51.0  ...    96.0  1101053020003  336.0
# 1101053020004    24.0    59.0    59.0  ...    98.0  1101053020004  355.0
# ...               ...     ...     ...  ...     ...            ...    ...
# 1125074022801    23.0    71.0    78.0  ...    87.0  1125074022801  363.0
# 1125074023001    47.0    41.0    57.0  ...   138.0  1125074023001  417.0
# 1125074023002    54.0    55.0    61.0  ...   112.0  1125074023002  436.0
# 1125074023003    55.0    65.0   100.0  ...   154.0  1125074023003  553.0
# 1125074023004    36.0    49.0    81.0  ...   131.0  1125074023004  445.0
#
# [18538 rows x 8 columns]

# %%
prob_df = x.copy()


#기사를 보아하니 배달앱 사용자가 우리 인구의 반
theta = 0.5

for i in range(len(prob_df)) :
  for j in range(6) :
    if j == 0 :
      prob_df.iloc[i,j] =  prob_df.iloc[i, 7] * 0.05 * theta / prob_df.iloc[i,j]
    elif j == 1 :
      prob_df.iloc[i,j] =  prob_df.iloc[i, 7] * 0.29 * theta / prob_df.iloc[i,j]
    elif j == 2 :
      prob_df.iloc[i,j] =  prob_df.iloc[i, 7] * 0.35 * theta / prob_df.iloc[i,j]
    elif j == 3 :
      prob_df.iloc[i,j] =  prob_df.iloc[i, 7] * 0.22 * theta / prob_df.iloc[i,j]
    elif j == 4 :
      prob_df.iloc[i,j] =  prob_df.iloc[i, 7] * 0.07 * theta / prob_df.iloc[i,j]
    elif j == 5 :
      prob_df.iloc[i,j] =  prob_df.iloc[i, 7] * 0.02 * theta / prob_df.iloc[i,j]


prob_df
# Out:
#                  10대인구수    20대인구수    30대인구수  ...    60대인구수          집계구코드     합계
# 집계구코드                                        ...
# 1101053010001  0.520000  0.766780  0.634884  ...  0.045882  1101053010001  312.0
# 1101053020001  0.201087  0.958036  1.438889  ...  0.040217  1101053020001  370.0
# 1101053020002  0.197674  0.850000  1.122642  ...  0.050746  1101053020002  340.0
# 1101053020003  0.247059  0.994286  1.152941  ...  0.035000  1101053020003  336.0
# 1101053020004  0.369792  0.872458  1.052966  ...  0.036224  1101053020004  355.0
# ...                 ...       ...       ...  ...       ...            ...    ...
# 1125074022801  0.394565  0.741338  0.814423  ...  0.041724  1125074022801  363.0
# 1125074023001  0.221809  1.474756  1.280263  ...  0.030217  1125074023001  417.0
# 1125074023002  0.201852  1.149455  1.250820  ...  0.038929  1125074023002  436.0
# 1125074023003  0.251364  1.233615  0.967750  ...  0.035909  1125074023003  553.0
# ...

# %%
cost_df = x.copy()

for i in range(len(a)) :
  for j in range(6) :
    cost_df.iloc[i,j] = prob_df.iloc[i,j] * cost_df.iloc[i,j]

cost_df
# Out:
#                10대인구수  20대인구수  30대인구수  ...  60대인구수          집계구코드     합계
# 집계구코드                                  ...
# 1101053010001   7.800  45.240  54.600  ...    3.12  1101053010001  312.0
# 1101053020001   9.250  53.650  64.750  ...    3.70  1101053020001  370.0
# 1101053020002   8.500  49.300  59.500  ...    3.40  1101053020002  340.0
# 1101053020003   8.400  48.720  58.800  ...    3.36  1101053020003  336.0
# 1101053020004   8.875  51.475  62.125  ...    3.55  1101053020004  355.0
# ...               ...     ...     ...  ...     ...            ...    ...
# 1125074022801   9.075  52.635  63.525  ...    3.63  1125074022801  363.0
# 1125074023001  10.425  60.465  72.975  ...    4.17  1125074023001  417.0
# 1125074023002  10.900  63.220  76.300  ...    4.36  1125074023002  436.0
# 1125074023003  13.825  80.185  96.775  ...    5.53  1125074023003  553.0
# 1125074023004  11.125  64.525  77.875  ...    4.45  1125074023004  445.0
#
# [18538 rows x 8 columns]

# %%
df_code = df['집계구코드']
df = df.groupby(df['집계구코드'])
df_final = round(pd.DataFrame(df.sum()))

tmp = []

for i in range(len(df_final)) :
  tmp.append(df_final.iloc[i,0])
print(tmp)
# Out:
# [312.0, 370.0, 340.0, 336.0, 355.0, 402.0, 449.0, 355.0, 362.0, 455.0, 494.0, 420.0, 446.0, 337.0, 410.0, 278.0, 295.0, 369.0, 349.0, 481.0, 509.0, 341.0, 335.0, 386.0, 266.0, 464.0, 390.0, 336.0, 503.0, 316.0, 543.0, 436.0, 439.0, 973.0, 286.0, 304.0, 399.0, 602.0, 366.0, 388.0, 397.0, 592.0, 512.0, 486.0, 259.0, 591.0, 327.0, 422.0, 221.0, 573.0, 257.0, 349.0, 557.0, 453.0, 759.0, 529.0, 373.0, 384.0, 467.0, 547.0, 270.0, 505.0, 458.0, 434.0, 297.0, 790.0, 1790.0, 355.0, 351.0, 296.0, 85.0, 238.0, 101.0, 609.0, 499.0, 447.0, 581.0, 473.0, 493.0, 391.0, 391.0, 517.0, 374.0, 370.0, 385.0, 414.0, 433.0, 420.0, 323.0, 340.0, 518.0, 357.0, 430.0, 375.0, 53.0, 120.0, 392.0, 352.0, 415.0, 464.0, 313.0, 457.0, 472.0, 339.0, 377.0, 346.0, 506.0, 395.0, 447.0, 448.0, 357.0, 478.0, 457.0, 508.0, 501.0, 448.0, 449.0, 228.0, 488.0, 596.0, 412.0, 440.0, 518.0, 352.0, 333.0, 432.0, 709.0, 328.0, 271.0, 566.0, 331.0, 371.0, 387.0, 426.0, 334.0, 358.0, 501.0, 389.0, 466.0, 444.0, 406.0, 531.0, 442.
# ...

# %%
a = df_final.index
a_list = []

for i in range(len(a)) :
  a_list.append(a[i])

# %%
df_final = pd.DataFrame({"집계구코드":a_list, "총생활인구수":tmp})
print(df_final)
# Out:
#                집계구코드  총생활인구수
# 0      1101053010001   312.0
# 1      1101053020001   370.0
# 2      1101053020002   340.0
# 3      1101053020003   336.0
# 4      1101053020004   355.0
# ...              ...     ...
# 18558  1125074022801   363.0
# 18559  1125074023001   417.0
# 18560  1125074023002   436.0
# 18561  1125074023003   553.0
# 18562  1125074023004   445.0
#
# [18563 rows x 2 columns]

# %%
f = open('/content/drive/MyDrive/배달_인구.txt', 'w')
f.write("base_year^tot_oa_cd^item^value\n")


for i in range(len(df_final)) :
  string = '2019' + '^' + str(df_final.iloc[i,0]) + '^' + '_' +  '^' + str(df_final.iloc[i,1]) + "\n"
  f.write(string)

f.close()
